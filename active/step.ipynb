# %%
import numpy as np
import matplotlib.pyplot as plt

# 阶跃函数
f = lambda x: np.where(x >= 0,1,-1)
x = np.linspace(-10,10,1000)
y = f(x)

# %% [markdown]
# $step(x)=\begin{matrix}
# 1|x >= 0 \\
# -1|x < 0
# \end{matrix}$

# %%
# 绘制图像
plt.plot(y)
plt.title('step function')
plt.grid()

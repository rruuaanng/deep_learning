# %%
import numpy as np
import matplotlib.pyplot as plt

# ReLU函数（隐藏层
f = lambda x: np.maximum(0, x)
x = np.random.randn(10)
res = f(x)

# %% [markdown]
# $ReLU(x)=\begin{matrix}
# x|x>=0 \\
# 0|x<0
# \end{matrix}$

# %%
# 绘制图像
plt.plot(res)
plt.title('ReLU function')
plt.grid()
